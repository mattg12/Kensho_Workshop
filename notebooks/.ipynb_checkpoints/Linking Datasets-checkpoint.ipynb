# %% [markdown]
# # Kensho Technologies Workshop - January 29th, 2019
# ## Linking Datasets
#
# Purpose of this notebook is an exercise in attempt to combine two datasets with imperfect information.
#
# ### To Dos:
#
# 1. What are differences in how names are written across datasets?
# 2. Find 100 new links between the datasets
# 3. Find 100 new entities in Dataset 1 not in Dataset 2

# %%
import numpy as np
import pandas as pd
import nltk
import matplotlib.pyplot as plt

# %%
# import datasets
ishares = pd.read_csv('../data/ai_meetup_data/ishares_companies.csv')
wikidata = pd.read_csv('../data/ai_meetup_data/wikidata_companies.csv')
labels = pd.read_csv('../data/ai_meetup_data/labeled_data.csv')

# %%
ishares.head()
# Out:
#    ishares_id                    Name Country      Sector Ticker  \
# 0           0                    ENEL   Italy   Utilities   ENEL
# 1           1                     ENI   Italy      Energy    ENI
# 2           2         INTESA SANPAOLO   Italy  Financials    ISP
# 3           3               UNICREDIT   Italy  Financials    UCG
# 4           4  ASSICURAZIONI GENERALI   Italy  Financials      G
#
#     Market Value
# 0  35,606,728.17
# 1  30,934,624.17
# 2  25,171,216.82
# 3  17,460,161.24
# 4  11,332,119.83

# %%
wikidata.head()
# Out:
#   wikidata_id       item_title                   country
# 0    Q1191932         0verflow                       NaN
# 1    Q4545742            1-2-3                    Norway
# 2    Q4545758   1-800 Contacts  United States of America
# 3    Q4545749   1-800-FREE-411  United States of America
# 4    Q4545754  1-800-GOT-JUNK?                       NaN

# %%
labels.head()
# Out:
#    ishares_id wikidata_id
# 0           0     Q651222
# 1           1     Q565594
# 2           2    Q1343118
# 3           3      Q45568
# 4           4     Q670482

# %% [markdown]
# ### Data Preparation

# %%
# rename columns of wikidata dataset to match relevant columns of ishares data
wikidata.rename(columns={'item_title': 'Name', 'country': 'Country'}, inplace=True)
# Out:
#   wikidata_id             Name                   Country
# 0    Q1191932         0verflow                       NaN
# 1    Q4545742            1-2-3                    Norway
# 2    Q4545758   1-800 Contacts  United States of America
# 3    Q4545749   1-800-FREE-411  United States of America
# 4    Q4545754  1-800-GOT-JUNK?                       NaN

# %%
# change Name to all lowercase for both datasets
ishares.Name = ishares.Name.str.lower()
wikidata.Name = wikidata.Name.str.lower()

# %% [markdown]
# ## Exploratory Data Analysis
#
# ### 1. Metadata
# What can I learn about each dataset from the information given, before getting into any NLP or feature engineering?
#
#     -Country data
#     -Industry data
#     -Company Size
#     -Alphabetical Distribution

# %%
# ishares data
ishares.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3836 entries, 0 to 3835
# Data columns (total 6 columns):
# ishares_id      3836 non-null int64
# Name            3836 non-null object
# Country         3836 non-null object
# Sector          3836 non-null object
# Ticker          3836 non-null object
# Market Value    3836 non-null object
# dtypes: int64(1), object(5)
# memory usage: 179.9+ KB

# %%
ishares.head()
# Out:
#    ishares_id                    Name Country      Sector Ticker  \
# 0           0                    enel   Italy   Utilities   ENEL
# 1           1                     eni   Italy      Energy    ENI
# 2           2         intesa sanpaolo   Italy  Financials    ISP
# 3           3               unicredit   Italy  Financials    UCG
# 4           4  assicurazioni generali   Italy  Financials      G
#
#     Market Value
# 0  35,606,728.17
# 1  30,934,624.17
# 2  25,171,216.82
# 3  17,460,161.24
# 4  11,332,119.83

# %%
# create a bar plot of country counts - ishares dataset
countries = ishares.Country.unique()

country_counts = ishares['Country'].value_counts()

plt.figure(figsize=(10,7))
country_counts.plot(kind='bar')
plt.title('Country Counts', fontsize=18)
plt.xlabel('Country', fontsize=14)
plt.xticks(rotation=45)
plt.ylabel('Count', fontsize=14);

# %%
# create a bar plot of country counts - wikidata
countries = wikidata.Country.unique()

country_counts = wikidata['Country'].value_counts()

plt.figure(figsize=(10,7))
country_counts.plot(kind='bar')
plt.title('Country Counts', fontsize=18)
plt.xlabel('Country', fontsize=14)
plt.xticks(rotation=45)
plt.ylabel('Count', fontsize=14);

# %% [markdown]
# ### Note
#
# Country data on wikidata is messier. I'll have to look into why there are so many different countries. Also, Country may not be a perfect feature. The same company could be associated with more than one country, and with a different country in each dataset.

# %%
wikidata.Country.unique()
# Out:
# array([nan, 'Norway', 'United States of America', 'United Kingdom',
#        'Russia', 'New Zealand', "People's Republic of China", 'Argentina',
#        'Japan', 'France', 'Canada', 'Germany', 'Australia', 'Denmark',
#        'Estonia', 'Italy', 'Latvia', 'Netherlands', 'Sweden', 'Spain',
#        'Czech Republic', 'Indonesia', 'United Arab Emirates', 'Poland',
#        'Uruguay', 'Taiwan', 'Turkey', 'Mexico', 'Austria', 'Bangladesh',
#        'Belgium', 'Ireland', 'Switzerland', 'India', 'Thailand',
#        'Luxembourg', 'Israel', 'Afghanistan', 'Finland', 'Peru',
#        'Bahrain', 'Saudi Arabia', 'Albania', 'South Korea',
#        'South Africa', 'Brazil', 'Serbia', 'Jordan', 'Iraq', 'Belarus',
#        'East Germany', 'The Bahamas', 'Colombia', 'Iran', 'Cyprus',
#        'Philippines', 'Soviet Union', 'Trinidad and Tobago', 'Ukraine',
#        'Rwanda', 'Bulgaria', 'Portugal', 'Singapore', 'Morocco',
#        'Malaysia', 'Algeria', 'Greece', 'Dominican Republic', 'Chile',
#        'Venezuela', 'Russian Empire', 'Egypt', 'Uganda', 'Croatia',
#        'Kingdom of the Netherlands', 'German Empire', 'Sri Lanka',
#        'Dutch Republic', 'Kingdom of Italy', 'Nigeria', 'Malta',
#        'Papua New Guinea', 'Nazi Germany', 'Slovenia',
#        'British Hong Kong', 'Qatar', 'Hong Kong', 'Liechtenstein',
#        'Somalia', 'Hungary', 'Lithuania', 'Costa Rica',
#        'United Kingdom of Great Britain and Ireland', 'Iceland',
#        'Kazakhstan', 'North Korea', 'Faroe Islands', 'Kuwait',
#        'Austria-Hungary', 'Libya', 'Namibia', 'Syria', 'Turkmenistan',
#        'Sudan', 'Pakistan', 'Monaco', 'Mongolia', 'Panama', 'Nauru',
#        'Nepal', 'Romania', 'Oman', 'Maldives', 'Tunisia', 'Vatican City',
#        'Angola', 'Slovakia', 'Jersey', 'Azerbaijan', 'Eritrea', 'Kenya',
#        'Zambia', 'Armenia', 'Zimbabwe', 'Ethiopia', 'Czechoslovakia'],
#       dtype=object)

# %%
# create a bar plot of sector counts
sectors = ishares.Sector.unique()

sector_counts = ishares['Sector'].value_counts()

plt.figure(figsize=(10,7))
sector_counts.plot(kind='bar')
plt.title('Sector Counts', fontsize=18)
plt.xlabel('Sector', fontsize=14)
plt.xticks(rotation=45)
plt.ylabel('Count', fontsize=14);
